# %%
import gensim
import os
import codecs
import re
import string
import io
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Articles from:
#     https://sites.google.com/site/qianmingjie/home/datasets/cnn-and-fox-news
#
# @inproceedings{qian2014unsupervised,
#   title={Unsupervised Feature Selection for Multi-View Clustering on Text-Image Web News Data},
#   author={Qian, Mingjie and Zhai, Chengxiang},
#   booktitle={Proceedings of the 23rd ACM International Conference on Conference on Information and Knowledge Management},
#   pages={1963--1966},
#   year={2014},
#   organization={ACM}
# }

# %%
os.chdir('/Users/7of9/Documents/Word2Vec/')
f = open('FOX/DocList.txt', 'r')
fox_list = f.readlines()

# %%
os.chdir('FOX/')
os.getcwd()
# Out:
# '/Users/7of9/Documents/Word2Vec/FOX'

# %%
fox_files = []
for file in fox_list:
    file = file.split("\\")[0] + "/" + file.split("\\")[1]
    file = file.replace("\n", "")
    fox_files.append(file)

# %%
fox_files[0:3]
# Out:
# ['foxnews_health/foxnews_health-00002045-20140101060012CST.txt',
#  'foxnews_health/foxnews_health-00002046-20140101053044CST.txt',
#  'foxnews_health/foxnews_health-00002047-20140101053001CST.txt']

# %%
def words(text):
    regex = re.compile('[' + '–' + re.escape(string.punctuation) + '0-9\\r\\t\\n]')   
    text = regex.sub(" ", text)
    words = text.split()
    wordsL = [word.lower() for word in words]
    return(wordsL)

# %%
# https://stackoverflow.com/questions/7691514/extracting-text-from-xml-using-python
from xml.etree import cElementTree as ET
from bs4 import BeautifulSoup

os.chdir('Raw/')
fox_docs = []
for text in fox_files[20:]:
    with open(text) as f:
        soup = BeautifulSoup(f, 'xml')
    content = soup.find_all('TEXT')
    fox_docs.append(words(str(content).replace('TEXT', '')))

# %%
fox_docs[0][0:9]
# Out:
# ['shoveling', 'snow', 'can', 'take', 'a', 'toll', 'on', 'your', 'body']

# %%
from gensim.models import Word2Vec
fox_model = Word2Vec(fox_docs, min_count=1, size=300)

# %%
print(fox_model)
# Out:
# Word2Vec(vocab=33743, size=300, alpha=0.025)

# %%
words = list(fox_model.wv.vocab)
print(words)
# Out:
# ['shoveling', 'snow', 'can', 'take', 'a', 'toll', 'on', 'your', 'body', 'particularly', 'heart', 'the', 'american', 'association', 'said', 'strenuous', 'activity', 'actually', 'increase', 'chances', 'of', 'having', 'attack', 'and', 'experts', 'say', 'there', 'are', 'some', 'people', 'who', 'should', 'never', 'even', 'pick', 'up', 'shovel', 'dr', 'marc', 'gillinov', 'cleveland', 'clinic', '“people', 'have', 'coronary', 'artery', 'disease', 'not', 'perform', '”', '“it', 'trigger', 'it’s', 'hard', 'work', 'cold', 'temperatures', 'also', 'contribute', 'to', 'risk', 'because', 'it', 'cause', 'arteries', 'tighten', 'blood', 'pressure', 'other', 'factors', 'include', 'high', 'cholesterol', 'peripheral', 'arterial', 'age', 'if', 'you', 'think', 'or', 'experiencing', 'shortness', 'breath', 'discomfort', 'in', 'left', 'arm', 'chest', 'pain', 'seek', 'medical', 'attention', 'immediately', 'lot', 's', 'got', 'be', 'this', 'sharp', 'knife', 'like', 'could', 'just', 'fact', 'most', 'common', 'description', 'related', 'is', 'might', 'feels', 'an', 'elephant', 'sitting', 're', 'get', 'stop', 'that', 'put', 'down', 'stay', 'inside', 'for', 'more', 'information', 'log', 'onto', 'americanheart', 'org', 'students', 'their', 'lunch', 'at', 'barre', 'town', 'elementary', 'school', 'vt', 'agriculture', 'department', 'friday', 'jan', 'making', 'permanent', 'rules', 'allow', 'schools', 'serve', 'larger', 'portions', 'lean', 'meat', 'whole', 'grains', 'lunches', 'meals', 'ap', 'photo', 'toby', 'talbot', 'file', 'says', 'guidelines', 'restricting', 'portion', 'size', 'were', 'originally', 'intended', 'combat', 'childhood', 'obesity', 'but', 'many', 'parents', 'complained', 'kids', 'weren', 't', 'getting', 'enough', 'eat', 'administrators', 'establishing', 'maximums', 'meats', 'too', 'limiting', 'make', 'difficult', 'plan', 'daily', 'eliminated', 'limits', 'temporary', 'basis', 'than', 'year', 'ago', 'thursday', 'officials', 'made', 'rule', 'change', 'was', 'announced', 'by', 'kevin', 'concannon', 'undersecretary', 'food', 'nutrition', 'consumer', 'services', 'he', 'has', 'delivered', 'its', 'promise', 'give', 'nutritionists', 'flexibility', 'meal', 'planning', 'when', 'i', 'wanted', 'look', 'cheryl', 'tiegs', 'late', 'she', 'epitome', 'beauty', 'tall', 'thin', 'blond', 'standing', 'feet', 'with', 'dark', 'brown', 'eyes', 'hair', 'strong', 'eyebrows', 'couldn', 'looked', 'any', 'different', 'spent', 'time', 'feeling', 'bad', 'about', 'what', 'wasn', 'then', 'saw', 'ali', 'macgraw', 'movie', 'love', 'story', 'those', 'thick', 'eyebrows—i', 'finally', 'recognized', 'possibility', 'my', 'own', 'health', 'com', 'foods', 'healthy', 'skin', 'today', 'am', 'troubled', 'society', 'definition', 'm', 'sure', 'how', 'started', 'breed', 'older', 'women', 'nothing', 'grew', 'admiring', 'grandmother', 'helen', 'hayes', 'jessica', 'tandy', 'seems', 'everywhere', 'turn', 'altered', 'erased', 'everything', 'mother', 'nature', 'gave', 'them', 'sad', 'thing', 'don', 'younger', 'untouched', 'peers', 'why', 'do', 'so', 'want', 'rid', 'features', 'unique', 'favor', 'cosmetic', 'surgery', 'enhanced', 'cookie', 'cutter', 'we', 'choice', 'buy', 'into', 'these', 'images', 'conscious', 'decision', 'true', 'isn', 'looking', 'supermodel', 'remember—they', 'freaks', 'twenty', 'something', 'barbie', 'doll', 'accepting', 'good', 'hope', 'things', 've', 'learned', 'will', 'help', 'see', 'winter', 'annoyances', 'solved', 'obsessing', 'instead', 'worrying', 'flaws', 'yourself', 'focus', 'right', 'tell', 'times', 'come', 'makeup', 'counter', 'fixated', 'shape', 'one', 'feature', 'they', 'overlook', 'else', 'woman', 'asks', 'me', 'her', 'nose', 'smaller', 'point', 'out', 'amazing', 'smile', 'show', 'enhance', 'lips', 'lipstick', 'gloss', 'often', 'pleasantly', 'surprised', 'sees', 'live', 'present', 'waste', 'much', 'energy', 'used', 'appreciating', 'now', 'makes', 'no', 'sense', 'obsess', 'pass', 'll', 'back', 'photos', 'from', 'years', 'realize', 'young', 'fresh', 'hated', 'arms', 'teenag ...

# %%
fox_model['genius']
# Out:
# array([ 3.82094039e-03,  1.30745745e-03, -9.10332706e-03, -2.32516276e-03,
#        -1.06732288e-04,  1.96831068e-03, -5.03703626e-03,  8.17466818e-04,
#         3.97827802e-03,  6.97908830e-03,  5.20160608e-03,  8.38918786e-04,
#        -1.07115209e-02, -1.15168449e-02,  1.77468068e-03, -4.53309575e-03,
#         6.53876876e-03, -1.47503335e-03, -1.28333196e-02, -5.10853902e-03,
#        -9.77502018e-03,  1.46842673e-02, -3.15617211e-03, -9.86349396e-03,
#         5.57695283e-03,  2.58869771e-02, -6.12218073e-03,  6.67498540e-03,
#        -2.93790060e-03,  6.67717727e-03, -5.85634029e-03,  1.13542739e-03,
#         6.18887832e-03, -5.86899556e-03, -1.37609243e-03,  1.96274668e-02,
#         6.45995699e-03, -6.94051757e-03,  7.58950366e-03, -1.84475631e-02,
#        -6.59740809e-03,  1.41148025e-03,  4.40571830e-03,  4.77423565e-03,
#         9.34634637e-03, -1.23883216e-02, -1.36010221e-03,  2.87775719e-03,
#        -7.27293640e-03, -1.08895721e-02, -1.41936541e-02,  6.27563195e-03,
#        -9.08560865e-03,  8.07639118e-03, -1.36401858e-02,  1.09374383e-02,
#         1.43186525e-02, -3.46582150e-03,  1.19870529e-03, -2.40738317e-02,
#         8.44792649e-03, -1.55464923e-02,  1.01640671e-02, -1.26925791e-02,
#        -1.79547127e-02, -7.74277002e-03,  3.53403715e-03,  4.20383690e-03,
#         9.88027453e-03,  4.26709047e-03,  5.11218840e-03, -7.35710515e-03,
#         1.24920264e-03, -4.55600256e-03,  4.20103641e-03,  7.55730085e-03,
#        -7.50340940e-03, -1.10061541e-02, -8.99638887e-03, -5.41138137e-03,
#         1.26841580e-02, -9.87380091e-03, -1.17367441e-02, -7.53524667e-03,
#        -1.31555228e-03,  4.22711251e-03, -5.96826011e-03,  3.96155025e-04,
#         5.78447105e-03,  1.85987388e-03,  1.17284954e-02,  9.32869222e-03,
#         1.73903047e-03, -5.49056474e-03,  7.82643352e-03,  9.21609905e-03,
#        -1.45196915e-03, -1.05277672e-02, -2.21448508e-03, -5.98090301e-05,
#        -8.05676915e-03, -7.28116464e-03,  1.56505611e-02, -1.09306304e-03,
#        -3.32217244e-03, -2.39408109e-03, -5.57536678e-03,  1.09185348e-03,
#        -4.74816374e-03, -2.09789500e-02, -4.72489232e-03,  9.95250419e-03,
#         4.81799990e-03, -8.47727642e-04, -8.34253430e-03,  1.05352085e-02,
#        -2.00349186e-03, -5.23710949e-03, -5.92842465e-03,  4.80191829e-03,
#         2.08556972e-04, -1.38454360e-03, -4.69286414e-03, -1.69445202e-02,
#        -2.44970969e-03,  6.21073367e-03, -3.64104140e-04, -4.90645366e-03,
#        -7.27344258e-03, -4.29176958e-03, -8.85544636e-04, -3.45526659e-03,
#        -8.58186558e-03,  8.11043289e-03,  1.43461779e-03, -1.80397846e-03,
#         1.58019792e-02,  1.57703331e-03,  6.04037242e-03,  1.44038210e-02,
#         4.42024041e-03,  2.02145521e-03, -6.03279518e-03,  2.90245540e-03,
#         1.67323090e-02,  1.38970073e-02,  3.01791006e-03,  2.82041728e-03],
#       dtype=float32)

# %%
os.chdir('/Users/7of9/Documents/Word2Vec/')
fox_model.wv.save_word2vec_format('fox_model.txt', binary=False)

# %%
from scipy.spatial.distance import cosine

def bais_genius(model):
    man_diff = cosine(model['man'], model['genius'])
    woman_diff = cosine(model['woman'], model['genius'])
    return man_diff - woman_diff

# %%
bais_genius(fox_model)
# Out:
# -0.09093654155731201
